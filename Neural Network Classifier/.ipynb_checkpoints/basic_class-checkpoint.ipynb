# %%
import pandas as pd
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from IPython import display
import pylab as plt
# %matplotlib inline
import numpy as np
import re

class TextAI():
    """
    Fast coding of text using machine learning
    """
    def __init__(self,active=False,batch_size=10,alpha=0.01):
        """
        Init classifier (multinomialNB for now) and lists to keep results
        """
        #Active learning flag
        self.active = active
        #Classifier
        self.clf = MultinomialNB(alpha=alpha,fit_prior=False)
        #Keep progress
        self.accuracy = []
        self.real_accuracy = []
        self.count = 0
        #Batch size
        self.batch_size = batch_size
        
    def load_database(self,filename):
        """
        Loads the database from file (right now from the 20newsgroups)
        """
        if filename == "news":
            # get data from Sklearn testing sets
            newsgroups_train = fetch_20newsgroups(
                   subset='train',
                   shuffle=True,
                   remove = ('headers', 'footers', 'quotes')
                   #categories = ['alt.atheism','talk.religion.misc','comp.graphics','sci.space']
                  )
            Small_words_dataset = newsgroups_train.data
            small_labels_dataset = newsgroups_train.target

            df_small_text = pd.DataFrame(Small_words_dataset)
            df_small_label = pd.DataFrame(small_labels_dataset)

            df_small = pd.concat([df_small_text,df_small_label],1)
            df_small.columns = ['Article_Text','Article_Label']
        
        self.data = df_small

    def process_text(self):
        """
        Create TF-IDF from the articles
        """
        df_small = self.data
        # replace the text with decommented text
        df_small.Article_Text = df_small.Article_Text.replace('>.*\n|.+: .*\n|.+writes:\n|\n',' ',regex=True)

        # lowercase
        df_small.Article_Text = df_small.Article_Text.str.lower()

        # tokenise
        df_small.Article_Text = df_small.Article_Text.replace("'","")
        df_small.Article_Text = df_small.Article_Text.replace("[^0-9a-z]+"," ",regex=True)

        # create basic word vectors
        vectorizer = TfidfVectorizer(stop_words='english')
        self.X_test = vectorizer.fit_transform(df_small.Article_Text)
        self.y_test = self.data.Article_Label.values
        
    def get_one(self):
        """
        Get next in list
        """
        #active learning get one
        return self.X_test[self.count,:]
    
    def label(self,to_label):
        """
        Here we hsould ask the user to give input
        """        
        self.y_test[self.count] = self.y_test[self.count]
        
    def batch_train(self):
        """
        Train classifier and keep progress
        """
        self.clf.partial_fit(self.X_test[self.count-self.batch_size:self.count,:],
                             self.y_test[self.count-self.batch_size:self.count],
                            classes=range(20))
        pred = self.clf.predict(self.X_test)
        self.accuracy.append(metrics.f1_score(self.y_test[:self.count], pred[:self.count], average='macro'))
        self.real_accuracy.append(metrics.f1_score(self.y_test[self.count:], pred[self.count:], average='macro'))

    def sort_next_labels(self,entr):
        """
        Get next batch of items to label
        """
        bs = self.batch_size

        #entr = np.apply_along_axis(lambda x: np.min(sorted(x)[2:])-np.max(sorted(x)[:2]), 1, entr[self.count:,:])
        entr2 = np.sum(entr[self.count:,:],1)
        
        order = np.argpartition(-entr2, bs)[:bs]+self.count
        #from collections import Counter
        #print(Counter(entr[order,:].argmax(1)).most_common())
        
        self.X_test[self.count:self.count+bs,:],self.X_test[order,:] = \
            self.X_test[order,:],self.X_test[self.count:self.count+bs,:]
        self.y_test[self.count:self.count+bs],self.y_test[order] = \
            self.y_test[order],self.y_test[self.count:self.count+bs]
        
    def batch_train_active(self):
        """
        Train classifier and keep progress
        """
        self.clf.partial_fit(self.X_test[self.count-self.batch_size:self.count,:],
                             self.y_test[self.count-self.batch_size:self.count],
                             classes=range(20))
        
        entr = self.clf.predict_proba(self.X_test)
        self.accuracy.append(metrics.f1_score(self.y_test[:self.count], entr[:self.count,:].argmax(1), average='macro'))
        self.real_accuracy.append(metrics.f1_score(self.y_test[self.count:], entr[self.count:,:].argmax(1), average='macro'))
        
        if self.count + self.batch_size >= len(entr):
            return None
        else:
            self.sort_next_labels(entr)


    def update_plot(self):
        """
        Plot results updating the results
        """
        plt.gca().cla() 
        plt.plot(range(0,self.count,self.batch_size),self.accuracy,label='F1-analyzed')
        plt.plot(range(0,self.count,self.batch_size),self.real_accuracy,label='F1-left')
        plt.xlim(10,len(self.data))
        plt.ylim(0,1)
        #plt.xscale("log")
        plt.legend(loc=4)
        display.clear_output(wait=True)
        display.display(plt.gcf()) 
       
        
    
    def classify(self):
        """
        Main driver
        """
        lendata  = len(self.data)
        while self.count < lendata-1:
            self.count += 1
            
            #Here we'd ask the user to give input, for now we have the data labeled
            #to_label = self.get_one()
            #self.label(to_label)
            
            #Next batch of labels
            if self.count%self.batch_size == 0:
                if self.active:
                    self.batch_train_active()
                else:
                    self.batch_train()
                    
                self.update_plot()

# %%
#RAndom sampling
c = TextAI(False,batch_size=100,alpha=0.01)
c.load_database("news")
c.process_text()
c.classify()

# %%
#Active learning. This works like shit actually
c = TextAI(active=True,batch_size=100,alpha=0.01)
c.load_database("news")
c.process_text()
c.classify()
